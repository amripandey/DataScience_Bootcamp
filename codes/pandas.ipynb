# %%
import pandas as pd

# %%
df = pd.read_csv('Sample-Spreadsheet-100-rows.csv', encoding='unicode_escape')

# %%
print( df.to_string())
# Out:
#       1                                                 Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre      3  -213.25    38.94     35                Nunavut          Storage & Organization   0.8
# 0     2                                               1.7 Cubic Foot Compact "Cube" Office Refrigerators       Barry French    293   457.81   208.16  68.02                Nunavut                      Appliances  0.58
# 1     3                                                 Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       Barry French    293    46.71     8.69   2.99                Nunavut  Binders and Binder Accessories  0.39
# 2     4                                                                                             R380      Clay Rozendal    483  1198.97   195.99   3.99                Nunavut    Telephones and Communication  0.58
# ...

# %%
sampledata = pd.read_csv('titanic.csv', encoding='unicode_escape')

# %%
print(sampledata)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# drop_row = sampledata.drop([0,1], inplace=True)
# drop_col = sampledata.drop("Age", axis=1, inplace=True)

# %%
subset = sampledata.loc[sampledata["Age"]>25, ["Name","Age"]]
print(subset)
# Out:
#                                                   Name   Age
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# 6                              McCarthy, Mr. Timothy J  54.0
# ..                                                 ...   ...
# 883                      Banfield, Mr. Frederick James  28.0
# 885               Rice, Mrs. William (Margaret Norton)  39.0
# 886                              Montvila, Rev. Juozas  27.0
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [413 rows x 2 columns]

# %%
subset2 = sampledata.loc[(sampledata["Survived"] == 1) & (sampledata["SibSp"] > 2), ["Name","Age", "SibSp"]]

print(subset2)
# Out:
#                                                   Name   Age  SibSp
# 68                     Andersson, Miss. Erna Alexandra  17.0      4
# 85   Backstrom, Mrs. Karl Alfred (Maria Mathilda Gu...  33.0      3
# 88                          Fortune, Miss. Mabel Helen  23.0      3
# 233                     Asplund, Miss. Lillian Gertrud   5.0      4
# 261                  Asplund, Master. Edvin Rojj Felix   3.0      4
# 341                     Fortune, Miss. Alice Elizabeth  24.0      3
# 726        Renouf, Mrs. Peter Henry (Lillian Jefferys)  30.0      3

# %%
#Ranking and sorting
sampledata.sort_values(by="Age", ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
sampledata["rank"] = sampledata["Age"].rank(method="min")

sampledata.sort_values(by='maxrank', ascending=True)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 831          832         1       2           Richards, Master. George Sibley
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
sampledata["Age"].sum()
sampledata.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare     maxrank        rank
# count  891.000000  891.000000  714.000000  714.000000
# mean     0.381594   32.204208  350.162465  350.162465
# std      0.806057   49.693429  207.461019  207.461019
# min      0.000000    0.000000    1.000000    1.000000
# 25%      0.000000    7.910400  168.750000  168.750000
# ...

# %%
sampledata.loc[(sampledata["Age"] == 28),["Survived", "Fare"]]
# Out:
#      Survived     Fare
# 23          1  35.5000
# 34          0  82.1708
# 83          0  47.1000
# 100         0   7.8958
# 105         0   7.8958
# 169         0  56.4958
# 200         0   9.5000
# 281         0   7.8542
# 313         0   7.8958
# 342         0  13.0000
# 355         0   9.5000
# 392         0   7.9250
# 399         1  12.6500
# 403         0  15.8500
# 423         0  14.4000
# 426         1  26.0000
# 430         1  26.5500
# 443         1  13.0000
# 508         0  22.5250
# 562         0  13.5000
# 635         1  13.0000
# 756         0   7.7958
# 848         0  33.0000
# 874         1  24.0000
# 883         0  10.5000

# %%
sampledata.loc[sampledata["Age"].isna(), ["PassengerId", "Age"]]
# Out:
#      PassengerId  Age
# 5              6  NaN
# 17            18  NaN
# 19            20  NaN
# 26            27  NaN
# 28            29  NaN
# ..           ...  ...
# 859          860  NaN
# 863          864  NaN
# 868          869  NaN
# 878          879  NaN
# 888          889  NaN
#
# [177 rows x 2 columns]
